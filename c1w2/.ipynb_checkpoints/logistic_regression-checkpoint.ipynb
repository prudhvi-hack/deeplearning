# %%
import numpy as np
from matplotlib import pyplot as plt
import h5py

# %%
train_dataset=h5py.File('datasets/train_catvnoncat.h5','r')
test_dataset=h5py.File("datasets/test_catvnoncat.h5","r")

# %%
X_orig=np.array(train_dataset['train_set_x'][:])
Y_orig=np.array(train_dataset['train_set_y'][:])

# %%
X_test=np.array(test_dataset['test_set_x'][:])
Y_test=np.array(test_dataset['test_set_y'][:])

# %%
classes=np.array(test_dataset["list_classes"][:])

# %%
Y_orig=Y_orig.reshape(1,Y_orig.shape[0])
Y_test=Y_test.reshape(1,Y_test.shape[0])

# %%
index=25
plt.imshow(X_orig[index])
plt.show()
print(classes[Y_orig[:,index]])
# Out:
# [b'cat']

# %%
index=28
plt.imshow(X_orig[index])
plt.show()
print(classes[Y_orig[:,index]])
# Out:
# [b'non-cat']

# %%
m_train=X_orig.shape[0]

# %%
m_test=X_test.shape[0]

# %%
num_px=X_orig.shape[1]

# %%
print(m_train,m_test,num_px,sep='\n')
# Out:
# 209
# 50
# 64

# %%
X_train_flatten=X_orig.reshape(X_orig.shape[0],-1).T
X_test_flatten=X_test.reshape(X_test.shape[0],-1).T

# %%
print(X_train_flatten.shape)
print(X_test_flatten.shape)
print(64*64*3)
# Out:
# (12288, 209)
# (12288, 50)
# 12288

# %%
train_set_x=X_train_flatten/255
test_set_x=X_test_flatten/255

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
def initialize(dim):
    w=np.zeros((dim,1))
    b=0
    return (w,b)

# %%
def propagate(w,b,X,y):
    m=X.shape[1]
    z=np.dot(w.T,X)+b
    A=sigmoid(z)
    cost=(-1/m)*(np.dot(np.log(A),y.T)+np.dot(np.log(1-A),1-y.T))
    dz=A-y
    dw=1/m*(np.dot(X,dz.T))
    db=1/m*np.sum(dz,axis=1)
  
    grads={"dw":dw,"db":db}
    
    return grads,cost

# %%
def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
    costs=[]
    for i in range(num_iterations):
        grads,cost=propagate(w,b,X,Y)
        dw=grads["dw"]
        db=grads["db"]
        w=w-learning_rate*dw
        b=b-learning_rate*db

        if (i%100==0):
            costs.append(cost)
        
        if(print_cost and i%100==0):
            print(f"cost at {i} iteration is {cost}")
    params={"w":w,"b":b}
    grads={"dw":dw,"db":db}
    return params,grads,costs

# %%
w, b, X, Y = np.array([[1.],[2.]]), 2., np.array([[1.,2.,-1.],[3.,4.,-3.2]]), np.array([[1,0,1]])
params, grads, costs = optimize(w, b, X, Y, num_iterations= 100, learning_rate = 0.009, print_cost = False)

print ("w = " + str(params["w"]))
print ("b = " + str(params["b"]))
print ("dw = " + str(grads["dw"]))
print ("db = " + str(grads["db"]))
# Out:
# w = [[0.19033591]
#  [0.12259159]]
# b = [1.92535983]
# dw = [[0.67752042]
#  [1.41625495]]
# db = [0.2191945]

# %%
def predict(w,b,X):
    a=sigmoid(np.dot(w.T,X)+b)
    y_predict=a>0.5
    y_predict=y_predict.astype(int)
    return y_predict

# %%
w = np.array([[0.1124579],[0.23106775]])
b = -0.3
X = np.array([[1.,-1.1,-3.2],[1.2,2.,0.1]])
print ("predictions = " + str(predict(w, b, X)))
# Out:
# predictions = [[1 1 0]]

# %%
def model(X_train,Y_train,X_test,Y_test,num_iterations=2000,learning_rate=0.5,print_cost=False):
    w,b=initialize(X_train.shape[0])
    
    params,grads,costs=optimize(w,b,X_train,Y_train,num_iterations,learning_rate,print_cost)
    
    w=params["w"]
    b=params["b"]
    
    train_predict=predict(w,b,X_train)
    test_predict=predict(w,b,X_test)
    
    print(f"train accuracy is {np.mean(1-(abs(train_predict-Y_train)))/m}")
    print(f"train accuracy is {np.mean(1-(abs(test_predict-Y_test)))/m}")

# %%
d = model(train_set_x, Y_orig, test_set_x, Y_, num_iterations = 2000, learning_rate = 0.005, print_cost = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-1302dd8ddd53> in <module>
# ----> 1 d = model(train_set_x, train_set_y, test_set_x, test_set_y, num_iterations = 2000, learning_rate = 0.005, print_cost = True)
#
# NameError: name 'train_set_y' is not defined
